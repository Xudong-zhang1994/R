# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
import scipy.stats as sps

# %%
d1=pd.read_csv("Relationship between nodes weighted degree and rank.csv")

# %%
X = d1['Ln(rank)']
Y = d1['Ln(weighted degree)']



plt.xlabel('Ln(rank)')
plt.ylabel('Ln(weighted degree)')

a = plt.plot(X,Y,'.', label='original data')
plt.xlim(0,4)
plt.ylim(0,20)

slope, intercept, r_value, p_value, std_err = sps.linregress(X, Y)

residual = X*slope + intercept
b = plt.plot(X, X*slope + intercept, 'r', label = 'fitted line') # Plot the regression line.


plt.legend()
plt.show()


print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
# Out:
# y = -1.081 x + 13.531
# Rsq =  0.8405599759690724
# p-value =  9.428164004549415e-19

# %%
d2=pd.read_csv("Patent knowledge network.csv")

# %%
X = d2['Ln(rank)']
Y = d2['Ln(weighted degree)']



plt.xlabel('Ln(rank)')
plt.ylabel('Ln(weighted degree)')

a = plt.plot(X,Y,'.', label='original data')
plt.xlim(0,6)
plt.ylim(0,8)

slope, intercept, r_value, p_value, std_err = sps.linregress(X, Y)

residual = X*slope + intercept
b = plt.plot(X, X*slope + intercept, 'r', label = 'fitted line') # Plot the regression line.


plt.legend()
plt.show()


print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
# Out:
# y = -1.791 x + 9.367
# Rsq =  0.9633978736396536
# p-value =  1.0218139672936508e-119
